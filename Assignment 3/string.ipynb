# %%
s = "Welcome to the python"
print(s)
# Out:
# Welcome to the python

# %%
s[6::-1]
# Out:
# 'emocleW'

# %% [markdown]
# Python strings are immutable

# %%
s
# Out:
# 'Welcome to the python'

# %% [markdown]
# Operations on Strings
# .Arithmetic Operations
# .Relational Operations
# .Logical Operations
# .Loops on Strings
# .Membership Operations

# %%
# Relational Operations

print("Hello" == "Hello") # equality
print("Hello"!= "World") # not equal
print("Hello" > "Hi") # greater than where e = 101 and i = 105
print("Hello" < "World") # less than where H = 72 and w = 87
print("Hello" >= "Hello") # greater than or equal to
# Out:
# True
# True
# False
# True
# True

# %%
# Logical Operations

"" and "World"
# Out:
# ''

# %%
#sorted

sorted(s)
# Out:
# [' ',
#  ' ',
#  ' ',
#  'W',
#  'c',
#  'e',
#  'e',
#  'e',
#  'h',
#  'h',
#  'l',
#  'm',
#  'n',
#  'o',
#  'o',
#  'o',
#  'p',
#  't',
#  't',
#  't',
#  'y']

# %%
# Loops on Strings
for i in "Bappy":
    print(i,end=" ")
# Out:
# B a p p y

# %%
#reverse sorted (decending order sort)
sorted(s, reverse=True)
# Out:
# ['y',
#  't',
#  't',
#  't',
#  'p',
#  'o',
#  'o',
#  'o',
#  'n',
#  'm',
#  'l',
#  'h',
#  'h',
#  'e',
#  'e',
#  'e',
#  'c',
#  'W',
#  ' ',
#  ' ',
#  ' ']

# %% [markdown]
# Strings Functions/Methods
# Capitalize
# Title
# Upper
# Lower
# Swapcase

# %%
print(s.capitalize())
print(s.title())
print(s.upper())
print(s.lower())
print(s.swapcase())
# Out:
# Welcome to the python
# Welcome To The Python
# WELCOME TO THE PYTHON
# welcome to the python
# wELCOME TO THE PYTHON

# %%
s = "My name is Bappy"

# %%
s.count("p")
s.find("B")
s.find("z")
# Out:
# -1

# %% [markdown]
# Find and index perform same activity but when that is not present index do error

# %%
s.index("z")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 s.index("z")
#
# ValueError: substring not found

# %%
s.endswith("pyy")
# Out:
# False

# %% [markdown]
# ### F-string
